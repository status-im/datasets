# %% [markdown]
# ![Eth load screen](./images/eth_load_screen.png)
#
# # EIP0 Ethereum shared values survey
#
# ## Context
#
# If you are reading this, your voice matters to the future guidance of Ethereum.
#
# The intent behind this survey is to create an open data-set of individual perspectives to help inform the Shared Values of Ethereum. Establishing cultural guidelines will help inform new community members and serve as our collective compass moving forward into the future.
#
# No question is required, anonymity is optional, so please submit even partial responses, any information you can provide is valid.
#
# Please submit your response before June 1st, so we can present the findings at the next Ethereum Bangkok meetup!
#
# For further discussion:
# https://gitter.im/ethereum/governance
# https://ethereum-magicians.org/t/share-your-values-on-the-eip0-shared-values-survey/454
#
# I encourage you to please share this survey with anyone you think can contribute meaningfully.
# https://goo.gl/forms/7jaaftDckYik5G1l2
#
# With love,
# Jarrad

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#EIP0-Ethereum-shared-values-survey" data-toc-modified-id="EIP0-Ethereum-shared-values-survey-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>EIP0 Ethereum shared values survey</a></span><ul class="toc-item"><li><span><a href="#Context" data-toc-modified-id="Context-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Context</a></span></li><li><span><a href="#Basic-imports" data-toc-modified-id="Basic-imports-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Basic imports</a></span></li><li><span><a href="#Loading-data" data-toc-modified-id="Loading-data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Loading data</a></span></li><li><span><a href="#Setting-up-for-Exploratory-Data-Analysis" data-toc-modified-id="Setting-up-for-Exploratory-Data-Analysis-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Setting up for Exploratory Data Analysis</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Role-models" data-toc-modified-id="Role-models-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Role models</a></span><ul class="toc-item"><li><span><a href="#Cleanup-text" data-toc-modified-id="Cleanup-text-1.5.1.1"><span class="toc-item-num">1.5.1.1&nbsp;&nbsp;</span>Cleanup text</a></span></li><li><span><a href="#Role-model-extraction" data-toc-modified-id="Role-model-extraction-1.5.1.2"><span class="toc-item-num">1.5.1.2&nbsp;&nbsp;</span>Role model extraction</a></span></li><li><span><a href="#Role-model-visualization" data-toc-modified-id="Role-model-visualization-1.5.1.3"><span class="toc-item-num">1.5.1.3&nbsp;&nbsp;</span>Role model visualization</a></span></li><li><span><a href="#TODO:-use-a-prettier-wordcloud." data-toc-modified-id="TODO:-use-a-prettier-wordcloud.-1.5.1.4"><span class="toc-item-num">1.5.1.4&nbsp;&nbsp;</span>TODO: use a prettier wordcloud.</a></span></li></ul></li><li><span><a href="#Organizations,-communities,-social-movements,-ideology-loosely-related" data-toc-modified-id="Organizations,-communities,-social-movements,-ideology-loosely-related-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Organizations, communities, social movements, ideology loosely related</a></span><ul class="toc-item"><li><span><a href="#avsa-wordcloud" data-toc-modified-id="avsa-wordcloud-1.5.2.1"><span class="toc-item-num">1.5.2.1&nbsp;&nbsp;</span>avsa wordcloud</a></span></li></ul></li><li><span><a href="#Ethereum-Values" data-toc-modified-id="Ethereum-Values-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Ethereum Values</a></span><ul class="toc-item"><li><span><a href="#Data-exploration" data-toc-modified-id="Data-exploration-1.5.3.1"><span class="toc-item-num">1.5.3.1&nbsp;&nbsp;</span>Data exploration</a></span></li><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-1.5.3.2"><span class="toc-item-num">1.5.3.2&nbsp;&nbsp;</span>Preprocessing</a></span></li><li><span><a href="#Dictionary-and-corpus-for-topic-modelling" data-toc-modified-id="Dictionary-and-corpus-for-topic-modelling-1.5.3.3"><span class="toc-item-num">1.5.3.3&nbsp;&nbsp;</span>Dictionary and corpus for topic modelling</a></span></li><li><span><a href="#Extracting-the-topics" data-toc-modified-id="Extracting-the-topics-1.5.3.4"><span class="toc-item-num">1.5.3.4&nbsp;&nbsp;</span>Extracting the topics</a></span></li><li><span><a href="#Topic-visualization" data-toc-modified-id="Topic-visualization-1.5.3.5"><span class="toc-item-num">1.5.3.5&nbsp;&nbsp;</span>Topic visualization</a></span></li></ul></li><li><span><a href="#Cleanup" data-toc-modified-id="Cleanup-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Cleanup</a></span></li></ul></li><li><span><a href="#Productionizing-topic-modelling" data-toc-modified-id="Productionizing-topic-modelling-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Productionizing topic modelling</a></span><ul class="toc-item"><li><span><a href="#Introducing-the-heavy-lifters" data-toc-modified-id="Introducing-the-heavy-lifters-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Introducing the heavy lifters</a></span></li><li><span><a href="#Sanity-check-on-Ethereum-values" data-toc-modified-id="Sanity-check-on-Ethereum-values-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>Sanity check on Ethereum values</a></span></li><li><span><a href="#Important-notes-on-visualization-interpretation" data-toc-modified-id="Important-notes-on-visualization-interpretation-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>Important notes on visualization interpretation</a></span></li><li><span><a href="#Avsa-wordcloud-on-Twitter" data-toc-modified-id="Avsa-wordcloud-on-Twitter-1.6.4"><span class="toc-item-num">1.6.4&nbsp;&nbsp;</span>Avsa wordcloud on Twitter</a></span></li></ul></li><li><span><a href="#Why-attracted-to-Ethereum" data-toc-modified-id="Why-attracted-to-Ethereum-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Why attracted to Ethereum</a></span><ul class="toc-item"><li><span><a href="#Avsa-wordcloud-on-Twitter" data-toc-modified-id="Avsa-wordcloud-on-Twitter-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>Avsa wordcloud on Twitter</a></span></li></ul></li><li><span><a href="#Happiest-Memory" data-toc-modified-id="Happiest-Memory-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Happiest Memory</a></span><ul class="toc-item"><li><span><a href="#Avsa-wordcloud-on-Twitter" data-toc-modified-id="Avsa-wordcloud-on-Twitter-1.8.1"><span class="toc-item-num">1.8.1&nbsp;&nbsp;</span>Avsa wordcloud on Twitter</a></span></li></ul></li><li><span><a href="#Frustration" data-toc-modified-id="Frustration-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Frustration</a></span><ul class="toc-item"><li><span><a href="#Avsa-wordcloud-on-Twitter" data-toc-modified-id="Avsa-wordcloud-on-Twitter-1.9.1"><span class="toc-item-num">1.9.1&nbsp;&nbsp;</span>Avsa wordcloud on Twitter</a></span></li></ul></li><li><span><a href="#Exhausting-things" data-toc-modified-id="Exhausting-things-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Exhausting things</a></span><ul class="toc-item"><li><span><a href="#Avsa-wordcloud-on-Twitter" data-toc-modified-id="Avsa-wordcloud-on-Twitter-1.10.1"><span class="toc-item-num">1.10.1&nbsp;&nbsp;</span>Avsa wordcloud on Twitter</a></span></li></ul></li><li><span><a href="#Failures" data-toc-modified-id="Failures-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Failures</a></span><ul class="toc-item"><li><span><a href="#Avsa-wordcloud-on-Twitter" data-toc-modified-id="Avsa-wordcloud-on-Twitter-1.11.1"><span class="toc-item-num">1.11.1&nbsp;&nbsp;</span>Avsa wordcloud on Twitter</a></span></li></ul></li><li><span><a href="#Good-member" data-toc-modified-id="Good-member-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Good member</a></span><ul class="toc-item"><li><span><a href="#Avsa-wordcloud-on-Twitter" data-toc-modified-id="Avsa-wordcloud-on-Twitter-1.12.1"><span class="toc-item-num">1.12.1&nbsp;&nbsp;</span>Avsa wordcloud on Twitter</a></span></li></ul></li><li><span><a href="#Your-values" data-toc-modified-id="Your-values-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>Your values</a></span><ul class="toc-item"><li><span><a href="#Avsa-wordcloud-on-Twitter" data-toc-modified-id="Avsa-wordcloud-on-Twitter-1.13.1"><span class="toc-item-num">1.13.1&nbsp;&nbsp;</span>Avsa wordcloud on Twitter</a></span></li></ul></li><li><span><a href="#Future" data-toc-modified-id="Future-1.14"><span class="toc-item-num">1.14&nbsp;&nbsp;</span>Future</a></span><ul class="toc-item"><li><span><a href="#Avsa-wordcloud-on-Twitter" data-toc-modified-id="Avsa-wordcloud-on-Twitter-1.14.1"><span class="toc-item-num">1.14.1&nbsp;&nbsp;</span>Avsa wordcloud on Twitter</a></span></li></ul></li><li><span><a href="#Fears" data-toc-modified-id="Fears-1.15"><span class="toc-item-num">1.15&nbsp;&nbsp;</span>Fears</a></span><ul class="toc-item"><li><span><a href="#Avsa-wordcloud-on-Twitter" data-toc-modified-id="Avsa-wordcloud-on-Twitter-1.15.1"><span class="toc-item-num">1.15.1&nbsp;&nbsp;</span>Avsa wordcloud on Twitter</a></span></li></ul></li><li><span><a href="#Life-Meaning" data-toc-modified-id="Life-Meaning-1.16"><span class="toc-item-num">1.16&nbsp;&nbsp;</span>Life Meaning</a></span><ul class="toc-item"><li><span><a href="#Avsa-wordcloud-on-Twitter" data-toc-modified-id="Avsa-wordcloud-on-Twitter-1.16.1"><span class="toc-item-num">1.16.1&nbsp;&nbsp;</span>Avsa wordcloud on Twitter</a></span></li></ul></li><li><span><a href="#Other-comments" data-toc-modified-id="Other-comments-1.17"><span class="toc-item-num">1.17&nbsp;&nbsp;</span>Other comments</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Basic imports

# %%
import pandas as pd

# %%
# Visualization

from wordcloud import WordCloud # TODO a prettier wordcloud
import matplotlib.pyplot as plt
from IPython.display import Image
import pprint # pretty printing

# %%
# Natural language processing

import spacy

from gensim.utils import simple_preprocess
from gensim.models import Phrases
from gensim.models.phrases import Phraser
import gensim.corpora as corpora
from gensim.models.ldamodel import LdaModel
from gensim.models import CoherenceModel

import pyLDAvis
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
# Out:
# /usr/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import warnings # remove all the deprecation warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# Download the model with 'python -m spacy download en_core_web_lg --user'
# Note: this is a 800MB model
#       'en_core_web_sm', 29MB can be used as alternative
#       see https://spacy.io/models/en#section-en_core_web_lg
nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# ## Loading data

# %%
df = pd.read_csv('./EIP0 Shared Values - 2018-06-05.csv')

# Anonymize answers
# Note, please remove the names of those who only
# wished to share their names with Status
df.drop(columns=['Name (or leave blank for anonymous)'], inplace = True)

# %%
df.head(3)
# Out:
#                      Timestamp  \
# 0  2018/05/23 5:58:27 PM GMT+2
# 1  2018/05/23 6:10:01 PM GMT+2
# 2  2018/05/23 6:13:40 PM GMT+2
#
#   Besides Vitalik, who are 3 or more people in the Ethereum Community that make good role models? What do you admire in them?  \
# 0  Rhys Lindmark -- Pushing to do good in the com...
# 1  Emin Gun Sirer, Vlad Zamfir, Stephan Tual\nEmi...
# 2  Vlad - just like his style. Nick Johnson - wel...
#
#   What are 3 or more organizations, communities, social movements and/or ideologies that are (loosely) related to Ethereum?  \
# 0  ETHPrize, Doge-Ethereum Art Project, Community...
# 1                     Universal Basic Income (UBI)\n
# 2  Cyber libertarianism / digital self-sovereignt...
#
#        What values does/should Ethereum embody? Why?  \
# 0  Transparency and Collaboration -- these result...
# 1  Openness, non-ideological, evidence-driven, de...
# 2  Openness, software for the people - by the peo...
#
# ...

# %% [markdown]
# ## Setting up for Exploratory Data Analysis

# %%
df.columns = ['Timestamp',
              'role_models',
              'orgs_com_mov_ideo',
              'values_ethereum',
              'why_attracted',
              'happiest_memory',
              'frustration',
              'exhausting',
              'failures',
              'good_member',
              'your_values',
              'future',
              'fears',
              'life_meaning',
              'other_comments'
              #'name'
             ]

# %%
# Columns with np.nan are replaced with blanks
df.fillna('', inplace = True)

# %%
df.head(3)
# Out:
#                      Timestamp  \
# 0  2018/05/23 5:58:27 PM GMT+2
# 1  2018/05/23 6:10:01 PM GMT+2
# 2  2018/05/23 6:13:40 PM GMT+2
#
#                                          role_models  \
# 0  Rhys Lindmark -- Pushing to do good in the com...
# 1  Emin Gun Sirer, Vlad Zamfir, Stephan Tual\nEmi...
# 2  Vlad - just like his style. Nick Johnson - wel...
#
#                                    orgs_com_mov_ideo  \
# 0  ETHPrize, Doge-Ethereum Art Project, Community...
# 1                     Universal Basic Income (UBI)\n
# 2  Cyber libertarianism / digital self-sovereignt...
#
#                                      values_ethereum  \
# 0  Transparency and Collaboration -- these result...
# 1  Openness, non-ideological, evidence-driven, de...
# 2  Openness, software for the people - by the peo...
#
#                                        why_attracted  \
# 0  Community -- best people ever.  I've seen ETHP...
# 1  Solidity - being able to run code on the block...
# ...

# %%
df.describe()
# Out:
#                           Timestamp role_models orgs_com_mov_ideo  \
# count                           207         207               207
# unique                          207         202               179
# top     2018/05/26 6:03:16 PM GMT+2
# freq                              1           4                27
#
#        values_ethereum why_attracted happiest_memory frustration exhausting  \
# count              207           207             207         207        207
# unique             191           195             182         180        178
# top
# freq                15            10              24          27         28
#
#        failures good_member your_values future fears life_meaning  \
# count       207         207         207    207   207          207
# unique      166         184         173    177   176          166
# top
# freq         37          21          33     29    27           40
#
#        other_comments
# count             207
# unique             69
# top
# ...

# %% [markdown]
# ## Exploratory Data Analysis
# ### Role models

# %% [markdown]
# #### Cleanup text
#
# Note cleanup can be improved but cleaning free text is notoriously hard as anyone can use arbitrary characters (even smileys).

# %%
def clean_punct(txt):
    x = txt.replace("\n", ". ")
    x = x.replace(" -- ", ": ")
    x = x.replace(" - ", ": ")
    x = x.replace(" + ", ", ")
    return x

# %%
# Checking on the first text
doc = nlp(clean_punct(df['role_models'][0]))
print(doc)
# Out:
# Rhys Lindmark: Pushing to do good in the community through work at ETHCommons, ETHDenver, Effective Altruism.  Always positive, pro-builder, bringing the community together and completely transparent.  Griff Green: Ultimate connector, going out of his way to organize events for good of Ethereum like Open Source Block Explorer and ScalingNow!: helps me with intro's all the time, Andy (CryptoWanderer): building ETHPrize interview set and obsessed with developer relations and moving the ecosystem forward all from a mindset of giving back and super hard worker.

# %%
# Extracting named entities
doc.ents
# Out:
# (Rhys Lindmark,
#  Griff Green,
#  Ultimate,
#  Ethereum like Open,
#  ScalingNow,
#  Andy,
#  CryptoWanderer,
#  ETHPrize)

# %%
# Check entities type
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Rhys Lindmark PERSON
# Griff Green PERSON
# Ultimate ORG
# Ethereum like Open WORK_OF_ART
# ScalingNow ORG
# Andy PERSON
# CryptoWanderer ORG
# ETHPrize ORG

# %%
del doc

# %% [markdown]
# #### Role model extraction

# %%
def role_models_extraction(txt):
    if txt == '':
        return ''
    doc = nlp(clean_punct(txt))
    role_models = []
    for named_entity in doc.ents:
        if named_entity.label_ == 'PERSON':
            txt = named_entity.text.replace(' ', '_')
            role_models.append(txt)
    return ', '.join(role_models)

# %%
df['role_models_extracted'] = df['role_models'].apply(role_models_extraction)

# %%
df['role_models_extracted']
# Out:
# 0                       Rhys_Lindmark, Griff_Green, Andy
# 1                     Vlad_Zamfir, Stephan_Tual, Stephan
# 2                           Nick_Johnson, Taylor_Monahan
# 3                 Nick_Johnson, Micah_Zoltu, Vlad_Zamfir
# 4
# 5               Vlad_Zamfir, Nick_Johnson, Martin_Swende
# 6               Peter_Szilagyi, Daniel_Nagy, Viktor_Tron
# 7               Piper_Merriam, Yoichi_Hirai, Vlad_Zamfir
# 8                                 Vlad_Zamfir, Joe_Lubin
# 9                   Gav, Christoph_Jentzsch, Ewald_Hesse
# 10            Vlad_Zamfir, Karl_Floersch, Hudson_Jameson
# 11     Vlad_Zamfir, Joseph_Lubin, Karl_Floersch, Grif...
# 12               Vlad_Zamphir, Griff_Green, Jori_Baylina
# 13                           Viktor_Tron, Lewis_Marshall
# 14              Nick_Johnson, Dan_Finlay, Hudson_Jameson
# 15         Dmitry_Buterin, Gavin_Wood, Alex_Van_de_Sande
# 16     Yoichi_Hirai, Alexey_Akhunov, Hudson_Jameson, ...
# ...

# %% [markdown]
# #### Role model visualization
#
# Note: preprocessing can be further improved as we have:
#   - Vlad, Vlad_Z, vlad, Vlad_Zhamfir
#   - Ethereum recognized as a person

# %%
# Concatenating all role models
role_models = ''
for idx, row in df['role_models_extracted'].iteritems():
    role_models += ', ' + row 

# Setting up the figure
plt.figure(figsize=(12,6))
wordcloud = WordCloud(background_color='white', width=600, height=300,
                      max_font_size=50, max_words=40).generate(role_models)
plt.imshow(wordcloud)
plt.title("Ethereum community role models", fontsize=20)
plt.axis("off")
plt.show()

# Cleanup
del role_models

# %% [markdown]
# #### TODO: use a prettier wordcloud.
#
# Unfortunately this wordcloud has poor visuals compared to what [avsa did on Twitter](https://twitter.com/avsa/status/1003655572590342145)
# <div style="width: 400px;">![inspiring](https://pbs.twimg.com/media/De2qrzkWkAAELLD.jpg)</div>

# %% [markdown]
# ### Organizations, communities, social movements, ideology loosely related

# %% [markdown]
# TODO. Given that we have a mix of organization names (Wikileaks, FSF ...), values (freedom, transparency, ...), ideologies (open-source, anarchism, liquid democracy ...), altcoins. This is tricky to process.
#
# #### avsa wordcloud
#
# <div style="width: 400px;">![Orgs](https://pbs.twimg.com/media/De2rdJXXUAAZsAO.jpg)</div>

# %% [markdown]
# ### Ethereum Values
#
# We extract coherent "topics" from the responses to what values should Ethereum embodies.
# We use LDA for that (Latent Dirichlet Allocation) which is a probabilistic method.
# Alternatively NMF (Nonnegative Matrix Factorization) which is a linear algebraic method can be used and might provide better or worse result.

# %%
df['values_ethereum']
# Out:
# 0      Transparency and Collaboration -- these result...
# 1      Openness, non-ideological, evidence-driven, de...
# 2      Openness, software for the people - by the peo...
# 3                   Resistance to government censorship.
# 4
# 5      Ethereum as a platform should remain neutral a...
# 6      "code is law" and blockchain immutability, bec...
# 7              Using incentive to make the world better.
# 8      Anarchism, because the network fundamentally d...
# 9
# 10     Immutable ledger, but willing to change consen...
# 11     Contribute to freedom and self-determination, ...
# 12     Inclusiveness. Solution to prisoner's dilemma ...
# 13           Freedom in scope of information technology.
# 14     - Embracing change via forks to improve the pr...
# 15     voluntary association of creators, self-govern...
# 16                             Ethics outside of the Law
# 17     There is this, which seems reasonable: https:/...
# ...

# %% [markdown]
# #### Data exploration

# %% [markdown]
# Exploration of preprocessing needs

# %%
df['values_ethereum'][0]
# Out:
# 'Transparency and Collaboration -- these result in speed and fairness.  Would like to see more on the innovation + moving faster side also.  Would be nice to have more formalized governance and a way to make things happen faster'

# %%
doc = nlp(df['values_ethereum'][0])

# %%
for token in doc:
    print(token.text)
del doc
# Out:
# Transparency
# and
# Collaboration
# --
# these
# result
# in
# speed
# and
# fairness
# .
#
# Would
# like
# to
# see
# more
# on
# the
# innovation
# +
# moving
# faster
# side
# also
# .
#
# Would
# be
# nice
# to
# have
# more
# formalized
# governance
# and
# a
# way
# to
# make
# things
# happen
# faster

# %% [markdown]
# Preprocessing needs:
# - Removing stopwords
#
# - bigrams and trigrams
#
#   Those represent 2 and 3 words that often come together
#
#   Stopwords needs to be removed before that (e.g. Transparency and Collaboration)
#
# - Lemmatization (i.e. transforming "enlightening" into "enlight")

# %% [markdown]
# #### Preprocessing

# %%
def topic_modelling_preprocess(txt):    
    # Remove stopwords
    stop_words = nlp.Defaults.stop_words
    stop_words.add('ethereum')
    
    cleaned = [word for word in simple_preprocess(txt, deacc = True) if word not in stop_words]
    if cleaned == []:
        return []
    
    # Lemmatization - TODO improve
    doc = nlp(" ".join(cleaned))    
    result = [token.lemma_ for token in doc if token.pos_ in {'NOUN', 'ADJ', 'VERB', 'ADV'}]
    return result

# %%
df['values_ethereum'][1]
# Out:
# 'Openness, non-ideological, evidence-driven, decentralised'

# %%
topic_modelling_preprocess(df['values_ethereum'][1])
# Out:
# ['openness', 'non', 'ideological', 'evidence', 'drive', 'decentralised']

# %%
eth_values = df['values_ethereum'].apply(topic_modelling_preprocess)

# %%
eth_values
# Out:
# 0      [transparency, collaboration, result, speed, f...
# 1      [openness, non, ideological, evidence, drive, ...
# 2      [openness, software, people, people, focus, ri...
# 3                   [resistance, government, censorship]
# 4                                                     []
# 5                    [platform, remain, neutral, embody]
# 6      [code, law, blockchain, immutability, need, un...
# 7                             [incentive, world, better]
# 8      [anarchism, network, fundamentally, derive, va...
# 9                                                     []
# 10     [immutable, ledger, willing, change, consensus...
# 11     [contribute, freedom, self, determination, res...
# 12     [inclusiveness, solution, prisoner, dilemma, c...
# 13             [freedom, scope, information, technology]
# 14     [embrace, change, fork, improve, protocol, sta...
# 15     [voluntary, association, creator, self, govern...
# ...

# %% [markdown]
# Notes
#   - The spaCy lemmatization is approximative. Openly and openness should have the same lemma for example.
#   - It seems like website needs to be cleanup as well, there are some 'http', 'www' lurking in the data
#   - I didn't use n-grams yet for this example

# %% [markdown]
# #### Dictionary and corpus for topic modelling

# %%
# Create Dictionary
id2word = corpora.Dictionary(eth_values)

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in eth_values]

# View
print(corpus[1])
print(id2word[14])
# Out:
# [(14, 1), (15, 1), (16, 1), (17, 1), (18, 1), (19, 1)]
# openness

# %% [markdown]
# #### Extracting the topics

# %%
num_topics = 7 # This is very important to tune.
               # The mainly 'people', 'respect' and 'censorship' topics appear for some values but not others for example

# %%
lda_model = LdaModel(corpus=corpus,
                     id2word=id2word,
                     num_topics=num_topics,
                     random_state=1337,
                     update_every=1,
                     chunksize=100,
                     passes=10,
                     alpha='auto',
                     per_word_topics=True)
del num_topics

# %% [markdown]
# #### Topic visualization

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.047*"collaboration" + 0.044*"open" + 0.042*"innovation" + '
#   '0.036*"mindedness" + 0.035*"tribalism" + 0.014*"don" + 0.012*"possible" + '
#   '0.009*"focus" + 0.008*"thing" + 0.008*"think"'),
#  (1,
#   '0.019*"community" + 0.017*"thing" + 0.014*"openness" + 0.014*"open" + '
#   '0.012*"end" + 0.011*"discussion" + 0.010*"new" + 0.010*"transparent" + '
#   '0.008*"term" + 0.008*"way"'),
#  (2,
#   '0.027*"transparency" + 0.017*"world" + 0.013*"people" + 0.013*"openness" + '
#   '0.012*"user" + 0.011*"integrity" + 0.008*"immutability" + 0.008*"share" + '
#   '0.008*"blockchain" + 0.008*"technology"'),
#  (3,
#   '0.067*"choice" + 0.032*"governmental" + 0.030*"freedom" + 0.015*"access" + '
#   '0.013*"create" + 0.012*"long" + 0.011*"social" + 0.011*"trust" + '
#   '0.010*"need" + 0.010*"privacy"'),
#  (4,
#   '0.081*"core" + 0.042*"process" + 0.042*"order" + 0.040*"force" + '
#   '0.040*"proof" + 0.014*"ideal" + 0.013*"human" + 0.012*"respect" + '
# ...

# %%
## Visualize the topics
# Note topic ID by pyLDAvis use a different index from the previous pretty-printed topics
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis # Interactive vizualization, doesn't work on Github
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 6      18.816619        1       1 -0.324068 -0.020192
# 3      17.663674        1       2  0.037093  0.160584
# 1      16.725467        1       3  0.077262 -0.053383
# 0      14.279910        1       4  0.061816 -0.108050
# 5      12.349099        1       5  0.075372 -0.062748
# 2      11.452897        1       6  0.036382  0.019449
# 4       8.712334        1       7  0.036142  0.064340, topic_info=     Category       Freq           Term      Total  loglift  logprob
# term
# 298   Default  30.000000         choice  30.000000  30.0000  30.0000
# 290   Default  18.000000           core  18.000000  29.0000  29.0000
# 51    Default  31.000000          value  31.000000  28.0000  28.0000
# 76    Default  31.000000     technology  31.000000  27.0000  27.0000
# 1     Default  17.000000  collaboration  17.000000  26.0000  26.0000
# ...

# %% [markdown]
# In case pyLDAvis is not installed, this is a non-interactive version of the output visualization
# with focus on the "community" topic

# %%
Image(filename="./images/eip0_values_vtest_community.png")

# %% [markdown]
# And here is a non-interactive visualization of the new "meritocracy" topic that popped up over the answers of Jun2 weekend

# %%
Image(filename="./images/eip0_values_vtest_meritocracy.png")

# %% [markdown]
# ### Cleanup

# %%
del id2word
del corpus
del eth_values
del vis

# %% [markdown]
# ## Productionizing topic modelling
#
# We put everything with done manually in a function so we can do topic modelling in a one-liner for the answers of the other questions.
#
# Note: we do lemmatization after n_grams to as many combinations like "non-technical" have a canonical use

# %% [markdown]
# ### Introducing the heavy lifters

# %%
def gen_stop_words(extra_stop_words):
    ## Expect a list of stop words in lowercase
    result = nlp.Defaults.stop_words
    for word in extra_stop_words:
        result.add(word)
    return result

# %%
def model_topics(txts, num_topics, stop_words, use_ngrams = False, n_grams_min_count = 5, n_grams_score_threshold = 1):
    # Note: here we process the whole dataframe series
    
    # Transform the serie into a list of list of words,
    # Remove stopwords at the same time
    cleaned = []
    for idx, txt in txts.iteritems():
        # Remove stopwords
        cleaned += [[word for word in simple_preprocess(txt, deacc = True) if word not in stop_words]]
    
    if use_ngrams:
        # Build bigrams and trigrams
        bigrams = Phraser(Phrases(cleaned, min_count=n_grams_min_count, threshold=n_grams_score_threshold))
        trigrams = Phraser(Phrases(bigrams[cleaned], threshold=n_grams_score_threshold))
        
        # Now create the bag of words with the new trigrams
        cleaned = [trigrams[bigrams[txt]] for txt in cleaned]
    
    # Lemmatization - TODO improve
    lemmatized = []
    for txt in cleaned:
        if txt == []:
            lemmatized += []
        else:
            doc = nlp(" ".join(txt))    
            lemmatized += [[token.lemma_ for token in doc if token.pos_ in {'NOUN', 'ADJ', 'VERB', 'ADV'}]]
            
    print("Snippet of keywords for topic modelling for the first 10 answers")
    print(lemmatized[0:10])
        
    # Create Dictionary
    id2word = corpora.Dictionary(lemmatized)

    # Term Document Frequency
    corpus = [id2word.doc2bow(text) for text in lemmatized]
    
    # Modelling
    lda_model = LdaModel(corpus=corpus,
                         id2word=id2word,
                         num_topics=num_topics,
                         random_state=1337,
                         update_every=1,
                         chunksize=100,
                         passes=10,
                         alpha='auto',
                         per_word_topics=True)
    
    ## Model performance
    print("\nModel performance\n")
    
    ## Perplexity
    print(f"""Perplexity: {lda_model.log_perplexity(corpus)}. Lower is better.
    See https://en.wikipedia.org/wiki/Perplexity.
    The best number of topics minimize perplexity.
    """)
    
    ## Coherence
    coherence = CoherenceModel(
        model=lda_model,
        texts=lemmatized,
        dictionary=id2word,
        coherence='c_v'
    )
    ## Corpus coherence
    print(f'Whole model coherence: {coherence.get_coherence()}.')
    
    ## By topic coherence
    topic_coherences = coherence.get_coherence_per_topic()
    print(f"""
By topic coherence. Higher is better.
    Measure how "well related" are the top words within the same topic.
    """)
    
    print(f'topic_id | {"top 3 keywords".rjust(45)} | topic coherence')
    for topic_id in range(num_topics):
        words_proba = lda_model.show_topic(topic_id, topn=3)
        words = [words for words,proba in words_proba]
        print(f'{topic_id:>8} | {str(words).rjust(45)} | {topic_coherences[topic_id]:>8.4f}')
    
    return lda_model, corpus, id2word

# %% [markdown]
# ### Sanity check on Ethereum values

# %%
stop_words = gen_stop_words(['ethereum'])

lda_model, corpus, id2word = model_topics(
    df['values_ethereum'], 7, stop_words,
    use_ngrams = True, n_grams_min_count = 1, n_grams_score_threshold = 1 # Need more data to have less permissive thresholds
)
# Out:
# Snippet of keywords for topic modelling for the first 10 answers
# ...

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.018*"want" + 0.014*"project" + 0.014*"honest" + 0.013*"process" + '
#   '0.012*"self" + 0.010*"don" + 0.010*"thing" + 0.009*"great" + '
#   '0.009*"embrace" + 0.008*"need"'),
#  (1,
#   '0.034*"people" + 0.016*"create" + 0.015*"good" + 0.013*"better" + '
#   '0.013*"human" + 0.012*"point" + 0.011*"right" + 0.010*"trust" + '
#   '0.009*"value" + 0.009*"progress"'),
#  (2,
#   '0.028*"transparency" + 0.020*"change" + 0.018*"integrity" + '
#   '0.017*"blockchain" + 0.014*"value" + 0.014*"immutability" + 0.012*"think" + '
#   '0.012*"dapp" + 0.012*"property" + 0.011*"try"'),
#  (3,
#   '0.022*"technology" + 0.022*"freedom" + 0.018*"community" + 0.016*"people" + '
#   '0.012*"individual" + 0.012*"privacy" + 0.010*"inclusion" + 0.009*"open" + '
#   '0.009*"human" + 0.009*"idea"'),
#  (4,
#   '0.027*"value" + 0.017*"good" + 0.016*"community" + 0.014*"thing" + '
#   '0.013*"open" + 0.013*"world" + 0.010*"collaboration" + 0.010*"network" + '
# ...

# %%
# Interactive vizualization, doesn't work on Github
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 3      21.154680        1       1 -0.017295 -0.174335
# 4      18.585634        1       2  0.137569 -0.008132
# 5      18.154702        1       3 -0.180958  0.023856
# 0      11.739202        1       4  0.076643  0.039959
# 1      10.397034        1       5 -0.033648 -0.022862
# 6      10.250383        1       6 -0.014541  0.127693
# 2       9.718366        1       7  0.032231  0.013821, topic_info=     Category       Freq             Term      Total  loglift  logprob
# term
# 20    Default  22.000000           people  22.000000  30.0000  30.0000
# 47    Default  19.000000            value  19.000000  29.0000  29.0000
# 0     Default  12.000000     transparency  12.000000  28.0000  28.0000
# 36    Default  11.000000       blockchain  11.000000  27.0000  27.0000
# 67    Default  14.000000          freedom  14.000000  26.0000  26.0000
# ...

# %% [markdown]
# The "productionized" topic modelling with n-grams analysis shows new insights.
#
# ### Important notes on visualization interpretation
#
# - Topics are build by association of keywords in the corpus
# - Changing the number of topics will have a huge impact on what is highlighted and word association.
#   For example keywords 'potential' and 'respect' can be the primary focus instead of 'technology' and 'openness'
#   For instance, the previous "meritocracy" keyword has been integrated in a "build, global, don't" topic.
# - The more people answers the best we can conclude on the values, some previously weak trends can become stronger.
# - The best topics (from a data science perspective) minimize perplexity and maximize coherence of the models.
# - Further tuning needs to be done as n-gram combinations like 'community_driven' do not count in 'community' anymore.
#
# Here are some snippets, make sure to check the repo for all the images.

# %%
Image(filename='./images/eip0_values_vprod_tech_freedom_community.png')

# %%
Image(filename='./images/eip0_values_vprod_build_global_dont.png')

# %% [markdown]
# ### Avsa wordcloud on Twitter
# </br>
# <div style="width: 600px;">![values](https://pbs.twimg.com/media/De2tXpUXcAA1s-J.jpg)</div>

# %% [markdown]
# ## Why attracted to Ethereum

# %%
stop_words = gen_stop_words(['ethereum'])

lda_model, corpus, id2word = model_topics(
    df['why_attracted'], 7, stop_words,
    use_ngrams = True, n_grams_min_count = 1, n_grams_score_threshold = 1 # Need more data to have less permissive thresholds
)
# Out:
# Snippet of keywords for topic modelling for the first 10 answers
# [['community_b', 'people_ve', 'see', 'ethprize', 'scale', 'idea', 'month', 'ago', 'community', 'effort', 'people', 'help', 'different', 'organization', 'volunteer', 'basis', 'cool', 'thing'], ['solidity', 'able', 'run', 'code_blockchain'], ['crypt', 'bham', 'decent', 'money', 'invest', 'try', 'pillar', 'community', 'help', 'integrate', 'blockchain', 'culture'], ['build', 'censorship_resistant', 'application', 'sure'], ['world_computer', 'smart_contract', 'attract', 'potential', 'decentralized_application'], ['liberating', 'economic_activity', 'omnipotent', 'government', 'control'], ['liberty', 'opportunity', 'want', 'build', 'cool'], ['ability_create', 'computer', 'program', 'run', 'verifiably'], ['fair', 'money', 'scale', 'world'], ['community', 'true', 'nerd', 'feel', 'lack', 'previous', 'life', 'decide', 'want', 'normal', 'nerdy', 'life', 'short', 'nerd', 'pay']]
#
# Model performance
#
# ...

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.015*"work" + 0.014*"want" + 0.013*"people" + 0.013*"potential" + '
#   '0.011*"time" + 0.010*"ecosystem" + 0.010*"life" + 0.008*"idea" + '
#   '0.008*"value" + 0.007*"project"'),
#  (1,
#   '0.019*"decentralized" + 0.016*"building" + 0.012*"think" + '
#   '0.012*"technology" + 0.012*"money" + 0.010*"stuff" + 0.009*"turn" + '
#   '0.008*"attractive" + 0.008*"blockchain" + 0.007*"idea"'),
#  (2,
#   '0.018*"people" + 0.011*"social" + 0.009*"community" + 0.009*"originally" + '
#   '0.008*"technical" + 0.007*"vision" + 0.007*"bitcoin" + 0.007*"exist" + '
#   '0.006*"change" + 0.006*"wasn"'),
#  (3,
#   '0.018*"world" + 0.017*"value" + 0.016*"possibility" + 0.012*"bitcoin" + '
#   '0.011*"believe" + 0.011*"community" + 0.010*"web" + 0.009*"smart_contract" '
#   '+ 0.009*"system" + 0.009*"freedom"'),
#  (4,
#   '0.024*"community" + 0.021*"promise" + 0.014*"build" + 0.013*"platform" + '
#   '0.013*"amazing" + 0.012*"open" + 0.012*"network" + 0.010*"institution" + '
# ...

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis # Interactive vizualization, doesn't work on Github
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 0      22.277074        1       1  0.060112 -0.061047
# 5      20.271853        1       2  0.148106  0.057321
# 4      15.358001        1       3 -0.024118 -0.167385
# 3      13.778423        1       4  0.032251  0.044605
# 2      12.044939        1       5 -0.159170  0.053223
# 6       8.727190        1       6 -0.063184  0.032720
# 1       7.542519        1       7  0.006002  0.040563, topic_info=     Category       Freq                    Term      Total  loglift  logprob
# term
# 166   Default  10.000000                 vitalik  10.000000  30.0000  30.0000
# 73    Default  15.000000              technology  15.000000  29.0000  29.0000
# 492   Default   9.000000                 promise   9.000000  28.0000  28.0000
# 156   Default   8.000000                  vision   8.000000  27.0000  27.0000
# 76    Default   7.000000           decentralized   7.000000  26.0000  26.0000
# ...

# %% [markdown]
# ### Avsa wordcloud on Twitter
#
# - missing

# %% [markdown]
# ## Happiest Memory

# %%
stop_words = gen_stop_words(['ethereum'])

lda_model, corpus, id2word = model_topics(
    df['happiest_memory'], 7, stop_words,
    use_ngrams = True, n_grams_min_count = 1, n_grams_score_threshold = 1 # Need more data to have less permissive thresholds
)
# Out:
# Snippet of keywords for topic modelling for the first 10 answers
# [['get', 'bounty', 'doge', 'bridge', 'donate', 'real_life', 'art', 'installation', 'launch', 'vancouver', 'summer'], ['show', 'friend', 'dapp', 'see', 'mind_blown'], ['get', 'interview', 'vice', 'magazine', 'cryptocurrency', 'trading', 'have', 'dialogue', 'vlad', 'transcribe', 'casper', 'lecture', 'common', 'english', 'read', 'have', 'security', 'guide', 'add', 'knowledgebase', 'contributing', 'project'], ['learn', 'initially', 'second_happi', 'get', 'lucky', 'price', 'movement'], ['devcon'], ['dao_hack', 'lot', 'fun', 'live', 'science', 'fiction', 'movie'], ['realize', 'zksnark', 'privacy', 'important'], ['devcon_shanghai', 'visit', 'parallel', 'universe', 'want'], ['day', 'period', 'end', 'token', 'sale', 'hack', 'involve', 'moment', 'know', 'world', 'go', 'change'], ['work', 'swim', 'team', 'member', 'place', 'remotely']]
#
# Model performance
#
# Perplexity: -7.386064616006701. Lower is better.
# ...

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.030*"work" + 0.028*"people" + 0.025*"devcon" + 0.015*"future" + '
#   '0.013*"cool" + 0.013*"person" + 0.012*"actually" + 0.012*"watch" + '
#   '0.012*"block" + 0.010*"think"'),
#  (1,
#   '0.014*"see" + 0.012*"friend" + 0.012*"money" + 0.012*"dapp" + 0.010*"early" '
#   '+ 0.010*"day" + 0.010*"go" + 0.009*"big" + 0.009*"work" + 0.009*"way"'),
#  (2,
#   '0.025*"work" + 0.016*"world" + 0.014*"realize" + 0.013*"great" + '
#   '0.013*"moment" + 0.013*"potential" + 0.012*"people" + 0.012*"change" + '
#   '0.010*"return" + 0.010*"truly"'),
#  (3,
#   '0.024*"build" + 0.016*"realise" + 0.014*"blockchain" + 0.014*"thing" + '
#   '0.014*"experience" + 0.012*"technology" + 0.011*"dev" + 0.011*"ether" + '
#   '0.011*"space" + 0.010*"start"'),
#  (4,
#   '0.012*"get" + 0.010*"community" + 0.009*"love" + 0.009*"time" + '
#   '0.009*"solve" + 0.009*"conversation" + 0.009*"value" + 0.008*"mean" + '
#   '0.008*"space" + 0.007*"foundation"'),
#  (5,
# ...

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis # Interactive vizualization, doesn't work on Github
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 5      21.764663        1       1 -0.136937 -0.058275
# 1      14.161354        1       2  0.025196 -0.035755
# 2      13.469473        1       3  0.023065  0.199752
# 4      13.263691        1       4  0.165961 -0.083201
# 6      13.151556        1       5 -0.067900 -0.061097
# 0      12.156283        1       6 -0.065053  0.034576
# 3      12.032979        1       7  0.055668  0.004000, topic_info=     Category       Freq          Term      Total  loglift  logprob
# term
# 333   Default   9.000000          help   9.000000  30.0000  30.0000
# 71    Default  20.000000          work  20.000000  29.0000  29.0000
# 42    Default  17.000000        devcon  17.000000  28.0000  28.0000
# 109   Default   9.000000         build   9.000000  27.0000  27.0000
# 185   Default  24.000000        people  24.000000  26.0000  26.0000
# 173   Default  18.000000          time  18.000000  25.0000  25.0000
# ...

# %% [markdown]
# ### Avsa wordcloud on Twitter
#
# - missing

# %% [markdown]
# ## Frustration

# %%
stop_words = gen_stop_words(['ethereum'])

lda_model, corpus, id2word = model_topics(
    df['frustration'], 7, stop_words,
    use_ngrams = True, n_grams_min_count = 1, n_grams_score_threshold = 1 # Need more data to have less permissive thresholds
)
# Out:
# Snippet of keywords for topic modelling for the first 10 answers
# ...

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.015*"think" + 0.015*"governance" + 0.014*"lack" + 0.013*"foundation" + '
#   '0.013*"need" + 0.012*"right" + 0.012*"good" + 0.012*"work" + 0.011*"hack" + '
#   '0.011*"problem"'),
#  (1,
#   '0.032*"community" + 0.022*"people" + 0.018*"thing" + 0.017*"project" + '
#   '0.016*"group" + 0.014*"think" + 0.013*"good" + 0.011*"time" + '
#   '0.010*"leader" + 0.010*"go"'),
#  (2,
#   '0.015*"decide" + 0.013*"software" + 0.013*"ve" + 0.012*"bad" + '
#   '0.012*"focus" + 0.012*"hard_fork" + 0.012*"money" + 0.012*"crypto" + '
#   '0.012*"price" + 0.012*"approach"'),
#  (3,
#   '0.014*"ico" + 0.014*"community" + 0.013*"value" + 0.011*"better" + '
#   '0.011*"world" + 0.011*"decision" + 0.011*"use" + 0.010*"help" + '
#   '0.009*"need" + 0.009*"build"'),
#  (4,
#   '0.016*"tool" + 0.013*"account" + 0.013*"protocol" + 0.012*"understand" + '
#   '0.010*"new" + 0.010*"development" + 0.009*"good" + 0.009*"time_think" + '
#   '0.009*"thing" + 0.008*"set"'),
#  (5,
# ...

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis # Interactive vizualization, doesn't work on Github
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 1      22.702399        1       1 -0.158211  0.066812
# 0      20.528568        1       2 -0.089045 -0.014864
# 3      15.289593        1       3  0.131447  0.156366
# 6      11.638259        1       4  0.067868 -0.139440
# 2      10.947026        1       5  0.040357 -0.058878
# 4       9.726947        1       6  0.032156  0.005059
# 5       9.167208        1       7 -0.024571 -0.015055, topic_info=     Category       Freq          Term      Total  loglift  logprob
# term
# 16    Default  23.000000        people  23.000000  30.0000  30.0000
# 15    Default  29.000000     community  29.000000  29.0000  29.0000
# 237   Default  18.000000         think  18.000000  28.0000  28.0000
# 213   Default   7.000000          fund   7.000000  27.0000  27.0000
# 297   Default   9.000000         group   9.000000  26.0000  26.0000
# 12    Default  15.000000    governance  15.000000  25.0000  25.0000
# ...

# %% [markdown]
# ### Avsa wordcloud on Twitter
#
# </br>
#
# <div style="width: 600px;">![Frustrations](https://pbs.twimg.com/media/De2uSsqX0AIUomM.jpg)</div>

# %% [markdown]
# ## Exhausting things

# %%
stop_words = gen_stop_words(['ethereum'])

lda_model, corpus, id2word = model_topics(
    df['exhausting'], 7, stop_words,
    use_ngrams = True, n_grams_min_count = 1, n_grams_score_threshold = 1 # Need more data to have less permissive thresholds
)
# Out:
# Snippet of keywords for topic modelling for the first 10 answers
# [['politic', 'unfreeze', 'governance', 'discussion', 'tough', 'probably', 'important', 'super', 'pump', 'move', 'technology', 'forward', 'suck', 'momentum', 'good', 'nature', 'human', 'being', 'thing'], ['rehash', 'old', 'argument', 'infight', 'different', 'coin', 'community'], ['purist', 'bitcoin', 'purist', 'immutability', 'purist', 'core', 'value', 'good', 'open', 'reasoning', 'better'], ['lack', 'strong', 'leadership'], ['discuss', 'eip', 'ico', 'spam', 'generally', 'deal', 'fud'], ['hard', 'fork', 'discussion', 'contradict', 'original', 'vision', 'value'], ['shitty', 'ico', 'scammer', 'industry'], ['immutability', 'fundamentalist', 'impatient', 'token_investor'], ['people', 'cry', 'bailout'], ['argument', 'blockchain', 'better']]
#
# Model performance
#
# Perplexity: -7.377893511802685. Lower is better.
#     See https://en.wikipedia.org/wiki/Perplexity.
#     The best number of topics minimize perplexity.
#
# ...

# %% [markdown]
# pprint.pprint(lda_model.print_topics())

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis # Interactive vizualization, doesn't work on Github
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 2      19.832961        1       1  0.227686  0.022196
# 6      19.520097        1       2 -0.100454 -0.058303
# 5      16.967575        1       3 -0.083628  0.161293
# 3      12.947021        1       4 -0.008492 -0.034480
# 0      11.356189        1       5 -0.026154 -0.082393
# 4       9.915490        1       6 -0.002543  0.019931
# 1       9.460666        1       7 -0.006416 -0.028244, topic_info=     Category       Freq          Term      Total  loglift  logprob
# term
# 55    Default  24.000000        people  24.000000  30.0000  30.0000
# 60    Default   9.000000       project   9.000000  29.0000  29.0000
# 84    Default   6.000000        reddit   6.000000  28.0000  28.0000
# 260   Default   5.000000          scam   5.000000  27.0000  27.0000
# 68    Default   9.000000         think   9.000000  26.0000  26.0000
# 217   Default   3.000000     tribalism   3.000000  25.0000  25.0000
# ...

# %% [markdown]
# ### Avsa wordcloud on Twitter
# </br>
# <div style="width: 400px;">![Exhausting](https://pbs.twimg.com/media/De2uvIUX4AE8Pzb.jpg)</div>

# %% [markdown]
# ## Failures

# %%
stop_words = gen_stop_words(['ethereum'])

lda_model, corpus, id2word = model_topics(
    df['failures'], 7, stop_words,
    use_ngrams = True, n_grams_min_count = 1, n_grams_score_threshold = 1 # Need more data to have less permissive thresholds
)
# Out:
# Snippet of keywords for topic modelling for the first 10 answers
# [['governance'], ['reasonable', 'clarity', 'timeline', 'important', 'network', 'change', 'pos_shard'], ['define', 'clear', 'philosophy', 'late', 'effectively', 'major', 'controversy'], ['lead'], ['slow', 'performance', 'need', 'prioritize', 'big', 'gripe', 'low', 'gas', 'limit', 'moment'], ['usability'], ['need_better', 'devs', 'user'], ['govern', 'hard', 'fork', 'adequately', 'engaging', 'blockchain', 'purport', 'provide', 'benefit'], ['bailout', 'bad', 'reason', 'bitcoin', 'genesis', 'block', 'mention', 'bailout'], ['totally', 'fail', 'deliver', 'decentralized', 'solution', 'nearly', 'highly', 'centralized', 'token', 'contract', 'owner', 'special', 'privilege', 'dapp', 'link', 'etherscan', 'dapps_use', 'metamask', 'infura']]
#
# Model performance
#
# Perplexity: -7.397795386432461. Lower is better.
#     See https://en.wikipedia.org/wiki/Perplexity.
#     The best number of topics minimize perplexity.
#
# ...

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.023*"set" + 0.015*"small" + 0.013*"didn" + 0.013*"open" + 0.013*"crypto" '
#   '+ 0.012*"bit" + 0.012*"team" + 0.012*"mindset" + 0.010*"implement" + '
#   '0.010*"consider"'),
#  (1,
#   '0.019*"application" + 0.018*"scale" + 0.017*"fail" + 0.015*"decision" + '
#   '0.015*"feel" + 0.013*"dev" + 0.013*"think" + 0.011*"adoption" + '
#   '0.011*"enterprise" + 0.011*"resource"'),
#  (2,
#   '0.025*"good" + 0.022*"community" + 0.019*"development" + 0.017*"thing" + '
#   '0.016*"improve" + 0.013*"ton" + 0.013*"research" + 0.013*"need" + '
#   '0.012*"fund" + 0.011*"spend"'),
#  (3,
#   '0.036*"governance" + 0.020*"work" + 0.020*"blockchain" + 0.016*"community" '
#   '+ 0.015*"example" + 0.015*"attention" + 0.015*"contribute" + 0.012*"people" '
#   '+ 0.012*"large" + 0.011*"need"'),
#  (4,
#   '0.024*"value" + 0.017*"fail" + 0.016*"public" + 0.015*"instead" + '
#   '0.014*"find" + 0.014*"community" + 0.013*"communication" + 0.012*"new" + '
# ...

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis # Interactive vizualization, doesn't work on Github
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 5      23.760309        1       1  0.103270 -0.074839
# 4      14.085804        1       2 -0.216424 -0.005418
# 3      13.661191        1       3  0.060802  0.116496
# 1      12.756388        1       4  0.019280  0.122818
# 2      12.552433        1       5  0.001150 -0.051695
# 0      12.360498        1       6  0.003245 -0.009558
# 6      10.823378        1       7  0.028676 -0.097804, topic_info=     Category       Freq              Term      Total  loglift  logprob
# term
# 0     Default   9.000000        governance   9.000000  30.0000  30.0000
# 120   Default  14.000000              work  14.000000  29.0000  29.0000
# 117   Default  11.000000              good  11.000000  28.0000  28.0000
# 271   Default   7.000000             value   7.000000  27.0000  27.0000
# 312   Default   5.000000               set   5.000000  26.0000  26.0000
# ...

# %% [markdown]
# ### Avsa wordcloud on Twitter
#
# </br>
# <div style="width: 600px;">![Failures](https://pbs.twimg.com/media/De2vEjJW0AApm6Q.jpg)</div>

# %% [markdown]
# ## Good member

# %%
stop_words = gen_stop_words(['ethereum'])

lda_model, corpus, id2word = model_topics(
    df['good_member'], 7, stop_words,
    use_ngrams = True, n_grams_min_count = 1, n_grams_score_threshold = 1 # Need more data to have less permissive thresholds
)
# Out:
# Snippet of keywords for topic modelling for the first 10 answers
# ...

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.024*"community" + 0.022*"thing" + 0.019*"open_mind" + 0.018*"good" + '
#   '0.017*"value" + 0.015*"people" + 0.011*"debate" + 0.010*"doesn" + '
#   '0.009*"role" + 0.009*"social"'),
#  (1,
#   '0.029*"contribute" + 0.019*"help" + 0.017*"project" + 0.015*"world" + '
#   '0.015*"question" + 0.015*"change" + 0.014*"good" + 0.012*"drive" + '
#   '0.012*"long_term" + 0.012*"improve"'),
#  (2,
#   '0.019*"governance" + 0.017*"personal" + 0.017*"different" + '
#   '0.015*"integrity" + 0.015*"ask" + 0.015*"passionate" + 0.013*"skill" + '
#   '0.013*"want" + 0.012*"kind" + 0.012*"open"'),
#  (3,
#   '0.032*"understand" + 0.019*"community" + 0.017*"opinion" + '
#   '0.016*"contribute" + 0.015*"people" + 0.014*"motive" + 0.014*"tech" + '
#   '0.013*"work" + 0.011*"security_structur" + 0.011*"application"'),
#  (4,
#   '0.026*"share" + 0.022*"community" + 0.017*"need" + 0.016*"educate" + '
#   '0.016*"learn" + 0.013*"discussion" + 0.012*"good" + 0.012*"help" + '
# ...

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis # Interactive vizualization, doesn't work on Github
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 4      18.750194        1       1 -0.074014 -0.010836
# 0      18.728829        1       2  0.215125 -0.026570
# 2      18.712423        1       3 -0.081062  0.029745
# 1      13.413936        1       4 -0.032491  0.128063
# 5      12.405128        1       5 -0.059240 -0.155270
# 6       9.082095        1       6 -0.004764 -0.024680
# 3       8.907394        1       7  0.036446  0.059548, topic_info=     Category       Freq           Term      Total  loglift  logprob
# term
# 137   Default   9.000000     contribute   9.000000  30.0000  30.0000
# 139   Default   5.000000     understand   5.000000  29.0000  29.0000
# 161   Default   8.000000          share   8.000000  28.0000  28.0000
# 84    Default   8.000000           care   8.000000  27.0000  27.0000
# 198   Default   7.000000           tech   7.000000  26.0000  26.0000
# ...

# %% [markdown]
# ### Avsa wordcloud on Twitter
#
# - Missing

# %% [markdown]
# ## Your values

# %%
stop_words = gen_stop_words(['ethereum'])

lda_model, corpus, id2word = model_topics(
    df['your_values'], 7, stop_words,
    use_ngrams = True, n_grams_min_count = 1, n_grams_score_threshold = 1 # Need more data to have less permissive thresholds
)
# Out:
# Snippet of keywords for topic modelling for the first 10 answers
# [['radical', 'self', 'reliance', 'inclusion', 'judgment', 'fear', 'listen', 'bias', 'action'], ['individuality', 'scared', 'fail', 'wrong', 'excited', 'learn'], ['global', 'advancement', 'science', 'technology'], ['integrity', 'drive', 'generally', 'productive'], ['non_aggression', 'principle'], ['recently', 'yolo'], ['imagine', 'better_world', 'try', 'work'], ['learn'], ['simplify', 'life', 'live', 'experience', 'goal', 'balance', 'act'], ['kind', 'give', 'end', 'high', 'return', 'take']]
#
# Model performance
#
# Perplexity: -7.10310204287102. Lower is better.
#     See https://en.wikipedia.org/wiki/Perplexity.
#     The best number of topics minimize perplexity.
#
# Whole model coherence: 0.4169547986746934.
#
# By topic coherence. Higher is better.
#     Measure how "well related" are the top words within the same topic.
#
# topic_id |                                top 3 keywords | topic coherence
# ...

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.040*"know" + 0.027*"need" + 0.024*"ability" + 0.019*"important" + '
#   '0.019*"difference" + 0.014*"person" + 0.014*"courage" + 0.013*"understand" '
#   '+ 0.013*"thing" + 0.011*"notion"'),
#  (1,
#   '0.025*"try" + 0.020*"self" + 0.019*"believe" + 0.019*"respect" + '
#   '0.014*"kindness" + 0.014*"open_mindedness" + 0.014*"curiosity" + '
#   '0.014*"end" + 0.014*"individual" + 0.014*"justice"'),
#  (2,
#   '0.020*"mind" + 0.014*"question" + 0.014*"freedom" + 0.014*"cooperation" + '
#   '0.014*"hard_work" + 0.014*"real" + 0.012*"harm" + 0.012*"satisfaction" + '
#   '0.012*"mediocre_passion" + 0.012*"extinguishes_candl"'),
#  (3,
#   '0.022*"open" + 0.022*"treat" + 0.022*"thing" + 0.020*"care" + 0.020*"work" '
#   '+ 0.019*"integrity" + 0.018*"empathy" + 0.016*"hard" + 0.015*"try" + '
#   '0.013*"honesty"'),
#  (4,
#   '0.029*"want" + 0.025*"love" + 0.023*"people" + 0.022*"good" + '
#   '0.019*"matter" + 0.014*"hear" + 0.014*"experience" + 0.014*"change" + '
# ...

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis # Interactive vizualization, doesn't work on Github
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 6      16.767321        1       1  0.012525  0.140643
# 3      16.353350        1       2 -0.204301 -0.049681
# 4      14.118650        1       3 -0.002488  0.035436
# 1      13.684724        1       4  0.010829  0.032582
# 5      13.122923        1       5  0.044113  0.047683
# 0      13.087013        1       6  0.037724 -0.105160
# 2      12.866018        1       7  0.101597 -0.101504, topic_info=     Category       Freq                Term      Total  loglift  logprob
# term
# 58    Default  14.000000                good  14.000000  30.0000  30.0000
# 83    Default   7.000000                know   7.000000  29.0000  29.0000
# 427   Default   6.000000                come   6.000000  28.0000  28.0000
# 89    Default   6.000000                want   6.000000  27.0000  27.0000
# 213   Default   6.000000               think   6.000000  26.0000  26.0000
# ...

# %% [markdown]
# ### Avsa wordcloud on Twitter
#
# </br>
#
# <div style="width: 600px;">![your_values](https://pbs.twimg.com/media/De2wZsxWAAAikcE.jpg)</div>

# %% [markdown]
# ## Future

# %%
stop_words = gen_stop_words(['ethereum'])

lda_model, corpus, id2word = model_topics(
    df['future'], 7, stop_words,
    use_ngrams = True, n_grams_min_count = 1, n_grams_score_threshold = 1 # Need more data to have less permissive thresholds
)
# Out:
# Snippet of keywords for topic modelling for the first 10 answers
# [['clearly', 'ultra', 'positive'], ['technology', 'actually', 'enhance', 'human', 'experience', 'distract'], ['great', 'human', 'replace', 'tbd'], ['overhaul', 'politics', 'country', 'end', 'coalition', 'think', 'canton', 'system', 'oppose', 'party', 'dictatorship'], ['hope', 'nation_state', 'gradually', 'lose', 'grip', 'society', 'rise'], ['interesting'], ['silly', 'beautiful'], ['fair', 'money', 'world'], ['chaotic', 'confused'], ['asshole', 'nice', 'people', 'mean', 'people']]
#
# Model performance
#
# Perplexity: -7.39582139688025. Lower is better.
#     See https://en.wikipedia.org/wiki/Perplexity.
#     The best number of topics minimize perplexity.
#
# Whole model coherence: 0.34087519888175816.
#
# By topic coherence. Higher is better.
#     Measure how "well related" are the top words within the same topic.
#
# topic_id |                                top 3 keywords | topic coherence
# ...

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.013*"time" + 0.010*"post_scarcity" + 0.010*"force" + 0.008*"hopefully" + '
#   '0.008*"subcontracted_deliver" + 0.008*"instead_shopp" + 0.008*"storefront" '
#   '+ 0.008*"personal_service" + 0.008*"case" + 0.008*"future_want"'),
#  (1,
#   '0.024*"good" + 0.022*"people" + 0.021*"future" + 0.020*"freedom" + '
#   '0.018*"community" + 0.016*"wealth" + 0.012*"state" + 0.011*"believe" + '
#   '0.011*"information" + 0.009*"medium"'),
#  (2,
#   '0.019*"capitalism" + 0.017*"create" + 0.013*"thing" + 0.012*"run" + '
#   '0.012*"abundance" + 0.011*"decentralized" + 0.011*"value" + '
#   '0.010*"blockchain" + 0.009*"account" + 0.009*"inequality"'),
#  (3,
#   '0.025*"future" + 0.019*"use" + 0.017*"power" + 0.017*"build" + '
#   '0.016*"people" + 0.015*"change" + 0.013*"money" + 0.013*"great" + '
#   '0.012*"work" + 0.011*"government"'),
#  (4,
#   '0.029*"people" + 0.024*"world" + 0.018*"society" + 0.015*"place" + '
# ...

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis # Interactive vizualization, doesn't work on Github
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 4      20.034088        1       1 -0.143387 -0.116344
# 5      16.258901        1       2 -0.042205  0.109944
# 6      14.468475        1       3 -0.001528  0.017378
# 1      14.122943        1       4 -0.013604  0.060795
# 3      13.371039        1       5 -0.004864  0.075817
# 2      12.203149        1       6  0.035552 -0.106154
# 0       9.541405        1       7  0.170036 -0.041436, topic_info=     Category       Freq                   Term      Total  loglift  logprob
# term
# 40    Default  23.000000                 people  23.000000  30.0000  30.0000
# 53    Default   5.000000                freedom   5.000000  29.0000  29.0000
# 120   Default   9.000000                   life   9.000000  28.0000  28.0000
# 28    Default   7.000000                society   7.000000  27.0000  27.0000
# 527   Default   4.000000             capitalism   4.000000  26.0000  26.0000
# ...

# %% [markdown]
# ### Avsa wordcloud on Twitter
#
#
#
# - missing

# %% [markdown]
# ## Fears

# %%
# Removing fear and worry keywords, they introduce useless noise
stop_words = gen_stop_words(['ethereum', 'fear', 'worry'])

lda_model, corpus, id2word = model_topics(
    df['fears'], 7, stop_words,
    use_ngrams = True, n_grams_min_count = 1, n_grams_score_threshold = 1 # Need more data to have less permissive thresholds
)
# Out:
# Snippet of keywords for topic modelling for the first 10 answers
# ...

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.025*"project" + 0.016*"people" + 0.015*"value" + 0.015*"developer" + '
#   '0.014*"control" + 0.014*"long_term" + 0.013*"good" + 0.012*"learn" + '
#   '0.010*"year" + 0.010*"chain"'),
#  (1,
#   '0.020*"governance" + 0.016*"world" + 0.014*"kind" + 0.014*"ecosystem" + '
#   '0.013*"scale" + 0.012*"people" + 0.012*"community" + 0.011*"trust" + '
#   '0.011*"public" + 0.011*"bad"'),
#  (2,
#   '0.015*"people" + 0.014*"vitalik" + 0.012*"true" + 0.011*"dangerous" + '
#   '0.009*"build" + 0.009*"greed" + 0.009*"coordination" + 0.009*"face" + '
#   '0.008*"course" + 0.008*"see"'),
#  (3,
#   '0.016*"society" + 0.014*"create" + 0.012*"end" + 0.011*"system" + '
#   '0.011*"new" + 0.011*"censorship" + 0.010*"human" + 0.010*"community" + '
#   '0.009*"people" + 0.009*"mining"'),
#  (4,
#   '0.016*"platform" + 0.014*"value" + 0.013*"great" + 0.012*"possible" + '
#   '0.012*"work" + 0.011*"governance" + 0.011*"doesn" + 0.011*"don" + '
#   '0.009*"win" + 0.008*"blockchain"'),
#  (5,
# ...

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis # Interactive vizualization, doesn't work on Github
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 3      16.911456        1       1 -0.058224 -0.029397
# 1      16.637461        1       2 -0.080461 -0.055294
# 0      14.574980        1       3 -0.019889  0.054087
# 2      14.514439        1       4  0.186392 -0.093825
# 5      14.448579        1       5 -0.040167 -0.032824
# 6      11.963448        1       6 -0.047990 -0.014736
# 4      10.949636        1       7  0.060339  0.171989, topic_info=     Category       Freq          Term      Total  loglift  logprob
# term
# 453   Default   7.000000       project   7.000000  30.0000  30.0000
# 90    Default   6.000000          time   6.000000  29.0000  29.0000
# 3     Default   9.000000    governance   9.000000  28.0000  28.0000
# 40    Default   8.000000         value   8.000000  27.0000  27.0000
# 105   Default   7.000000           big   7.000000  26.0000  26.0000
# 227   Default   7.000000         world   7.000000  25.0000  25.0000
# ...

# %% [markdown]
# Note: when playing with the data, at one point a topic
# ['fear', 'vitalik', 'system'] came up (i.e. bus factor?)

# %% [markdown]
# ### Avsa wordcloud on Twitter
#
# </br>
#
# <div style="width: 400px;">![Fears](https://pbs.twimg.com/media/De2yG41W0AAhAqT.jpg)</div>

# %% [markdown]
# ## Life Meaning

# %%
stop_words = gen_stop_words(['ethereum'])

lda_model, corpus, id2word = model_topics(
    df['life_meaning'], 7, stop_words,
    use_ngrams = True, n_grams_min_count = 1, n_grams_score_threshold = 1 # Need more data to have less permissive thresholds
)
# Out:
# Snippet of keywords for topic modelling for the first 10 answers
# [['self', 'reflection', 'help', 'work', 'hard', 'problem', 'vulnerable', 'fail', 'thing', 'succeed', 'thing', 'hard', 'personal', 'connection', 'introduce', 'people'], ['ascribe', 'give', 'time', 'feed', 'dog', 'make', 'positive', 'difference', 'somebody', 'life', 'fun'], ['witness', 'science', 'technology'], ['absurdist', 'today'], ['life_meaning', 'choose', 'fun'], ['good', 'vision', 'making_world', 'better_place'], ['story', 'real', 'fiction', 'thought', 'decide', 'accomplishment', 'life', 'meaning', 'experience', 'experience', 'past', 'story', 'collect', 'time'], ['meaning', 'come', 'release', 'fascination', 'fascinated', 'moment', 'moment', 'work', 'meaning', 'emerge', 'unbidden'], ['provide', 'stability', 'people', 'close', 'creative', 'hoping', 'work', 'help_people', 'know'], ['build', 'create', 'useful', 'have', 'purpose', 'good', 'thing', 'freedom', 'live', 'life', 'choose', 'good', 'question']]
#
# ...

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.033*"human" + 0.029*"thing" + 0.021*"good" + 0.018*"ve" + 0.015*"live" + '
#   '0.015*"freedom" + 0.015*"possible" + 0.015*"creation" + 0.014*"time" + '
#   '0.014*"idea"'),
#  (1,
#   '0.037*"people" + 0.036*"way" + 0.028*"family" + 0.022*"love" + '
#   '0.021*"think" + 0.021*"work" + 0.016*"want" + 0.014*"better" + '
#   '0.014*"gives_life" + 0.013*"life"'),
#  (2,
#   '0.030*"technology" + 0.025*"good" + 0.024*"life" + 0.021*"create" + '
#   '0.020*"opportunity" + 0.017*"love" + 0.015*"day" + 0.014*"try" + '
#   '0.013*"people" + 0.013*"child"'),
#  (3,
#   '0.023*"happy" + 0.022*"world" + 0.018*"learn" + 0.017*"humanity" + '
#   '0.015*"stuff" + 0.014*"able" + 0.014*"believe" + 0.014*"kid" + '
#   '0.014*"happiness" + 0.014*"feel"'),
#  (4,
#   '0.031*"experience" + 0.025*"people" + 0.023*"help" + 0.022*"sense" + '
#   '0.017*"build" + 0.016*"personal" + 0.013*"real" + 0.013*"future" + '
#   '0.012*"meaning" + 0.011*"face"'),
#  (5,
# ...

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis # Interactive vizualization, doesn't work on Github
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 1      19.726919        1       1  0.155310 -0.094234
# 3      16.274664        1       2  0.004907  0.165516
# 4      15.984439        1       3  0.056619  0.069600
# 6      15.079556        1       4 -0.178807 -0.065472
# 2      12.155445        1       5  0.035382 -0.051536
# 0      11.219802        1       6 -0.056501  0.010218
# 5       9.559174        1       7 -0.016909 -0.034092, topic_info=     Category       Freq           Term      Total  loglift  logprob
# term
# 410   Default  11.000000            way  11.000000  30.0000  30.0000
# 43    Default   7.000000     experience   7.000000  29.0000  29.0000
# 388   Default   5.000000          human   5.000000  28.0000  28.0000
# 27    Default   5.000000     technology   5.000000  27.0000  27.0000
# 148   Default   6.000000           find   6.000000  26.0000  26.0000
# ...

# %% [markdown]
# ### Avsa wordcloud on Twitter
# </br>
# <div style="width: 600px;">![life_meaning](https://pbs.twimg.com/media/De2w8JlXUAAwJ4D.jpg)</div>

# %% [markdown]
# ## Other comments

# %%
stop_words = gen_stop_words(['ethereum'])

lda_model, corpus, id2word = model_topics(
    df['other_comments'], 7, stop_words,
    use_ngrams = True, n_grams_min_count = 1, n_grams_score_threshold = 1 # Need more data to have less permissive thresholds
)
# Out:
# Snippet of keywords for topic modelling for the first 10 answers
# ...

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.032*"developer" + 0.012*"community" + 0.012*"platform" + 0.012*"project" '
#   '+ 0.012*"believe" + 0.012*"change" + 0.012*"great" + 0.012*"love" + '
#   '0.012*"thrive" + 0.012*"die"'),
#  (1,
#   '0.031*"great" + 0.022*"let" + 0.022*"code_law" + 0.022*"idea" + '
#   '0.021*"good_work" + 0.012*"far" + 0.012*"wait" + 0.012*"project" + '
#   '0.012*"level" + 0.012*"chance"'),
#  (2,
#   '0.021*"research" + 0.021*"look" + 0.014*"work" + 0.014*"way" + 0.014*"don" '
#   '+ 0.014*"need" + 0.014*"thing" + 0.014*"try" + 0.014*"old" + '
#   '0.014*"good_th"'),
#  (3,
#   '0.031*"community" + 0.031*"people" + 0.025*"work" + 0.025*"build" + '
#   '0.019*"need" + 0.019*"good" + 0.014*"great" + 0.013*"censorship" + '
#   '0.013*"feel" + 0.013*"project"'),
#  (4,
#   '0.025*"blockchain" + 0.025*"think" + 0.019*"need" + 0.019*"want" + '
#   '0.013*"people" + 0.013*"future" + 0.013*"come" + 0.013*"survey" + '
#   '0.013*"place" + 0.013*"project"'),
#  (5,
# ...

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis # Interactive vizualization, doesn't work on Github
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 6      20.305490        1       1 -0.095797  0.162896
# 5      20.095834        1       2  0.169802  0.036651
# 3      16.779769        1       3 -0.040907 -0.071693
# 4      16.328476        1       4 -0.064251 -0.096457
# 2      14.014043        1       5 -0.017906 -0.018320
# 0       6.308581        1       6  0.017168 -0.023106
# 1       6.167807        1       7  0.031890  0.010030, topic_info=     Category       Freq            Term      Total  loglift  logprob
# term
# 0     Default  10.000000           thank  10.000000  30.0000  30.0000
# 57    Default   4.000000           great   4.000000  29.0000  29.0000
# 140   Default   3.000000      blockchain   3.000000  28.0000  28.0000
# 397   Default   1.000000       developer   1.000000  27.0000  27.0000
# 2     Default   5.000000          survey   5.000000  26.0000  26.0000
# ...
